# %%
import config
import requests
import urllib3
import json
import re
from bs4 import BeautifulSoup
import pandas as pd

# %%
base = "https://api.genius.com"

# %%
def send_request(path, params=None, headers=None):
    requrl = '/'.join([base, path])
    token = "Bearer {}".format(config.access_token)
    if headers:
        headers['Authorization'] = token
    else:
        headers = {"Authorization": token}
        
    response = requests.get(url=requrl, params=params, headers=headers)
    response.raise_for_status()
    return response.json()

# %%
def normalize_name(name):
    return re.sub(r'\W+', '', name)

# %%
def verify_primary_artist(artist, song):
    normalized_artist = normalize_name(artist).lower()
    normalize_primary = normalize_name(song['primary_artist']['name']).lower()
    return normalized_artist == normalize_primary

# %%
def is_valid_song(song):
    is_valid = True
    is_valid &= '(' not in song['title']
    is_valid &= '-' not in song['title']
    is_valid &= 'annotated' not in song['url']
    return is_valid

# %%
def get_artist_id(artist):
    artist_encoded = artist.replace(' ', '%20')
    artist_hits = send_request('search/?q=%s' % artist_encoded)['response']['hits']
    for hit in artist_hits:
        if hit['type'] != 'song':
            continue
        if verify_primary_artist(artist, hit['result']):
            return hit['result']['primary_artist']['id']
    raise Exception('Artist %s Not Found' % artist)

# %%
def get_artist_songs(artist):
    try:
        artist_id = get_artist_id(artist)
    except:
        return []
    page = 1
    result = []
    while True:
        songs = send_request('artists/%s/songs?per_page=50&page=%s' % (artist_id, page))['response']['songs']
        if len(songs) == 0:
            return result
        for song in songs:
            if not is_valid_song(song):
                continue
            if verify_primary_artist(artist, song):
                result.append({
                    'artist': artist,
                    'title': song['title'],
                    'url': song['url'],
                    'lyrics': scrape_lyrics(song['url'])
                })
        print('Done with page %s' % page)
        page += 1

# %%
def scrape_lyrics(url):
    resp = requests.get(url)
    s = BeautifulSoup(resp.text)
    lyrics = s.findAll("div", {"class": "lyrics"})
    if len(lyrics) == 1:
        return lyrics[0].text
    return ''

# %%
get_artist_id('Denzel Curry')
# Out:
# 16690

# %%
more_artists = ['The Notorious BIG', '2pac', 'Travis Scott', 'Young Thug', 'Lil Wayne', 'Big Sean', 'Danny Brown',
               'J. Cole', 'Earl Sweatshirt', 'Future', 'Gucci Mane', 'JID', 'Lil Uzi Vert', '21 Savage',
                'Denzel Curry', 'Migos', 'Nas', 'Schoolboy Q', 'Skepta', 'Vince Staples', 'YG']

# %%
artists = ['The Weeknd', 'Kanye West', 'Kendrick Lamar', 'Eminem', 'Tyler the Creator', 'Jay-Z', 'Drake', 'Pusha-T']

# %%
def get_artist_songs_batch(artists):
    res = []
    for artist in artists:
        print("Starting to scrape %s's songs..." % artist)
        songs = get_artist_songs(artist)
        res.append(songs)
        print('Done')
    return res

# %%
all_songs = get_artist_songs_batch(artists)
# Out:
# Starting to scrape The Weeknd's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done
# Starting to scrape Kanye West's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done with page 23
# Done with page 24
# Done with page 25
# Done with page 26
# Done with page 27
# Done with page 28
# Done with page 29
# Done with page 30
# Done with page 31
# Done with page 32
# Done with page 33
# Done
# Starting to scrape Kendrick Lamar's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done
# Starting to scrape Eminem's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done with page 23
# Done with page 24
# Done with page 25
# Done
# Starting to scrape Tyler the Creator's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done
# Starting to scrape Jay-Z's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done
# Starting to scrape Drake's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done with page 23
# Done
# Starting to scrape Pusha-T's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done

# %%
all_songs = get_artist_songs_batch(more_artists)
# Out:
# Starting to scrape The Notorious BIG's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done
# Starting to scrape 2pac's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done with page 23
# Done
# Starting to scrape Travis Scott's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done
# Starting to scrape Young Thug's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done with page 23
# Done with page 24
# Done with page 25
# Done with page 26
# Done with page 27
# Done with page 28
# Done with page 29
# Done
# Starting to scrape Lil Wayne's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done with page 23
# Done with page 24
# Done with page 25
# Done with page 26
# Done with page 27
# Done with page 28
# Done with page 29
# Done with page 30
# Done with page 31
# Done with page 32
# Done with page 33
# Done with page 34
# Done with page 35
# Done with page 36
# Done with page 37
# Done with page 38
# Done with page 39
# Done with page 40
# Done with page 41
# Done with page 42
# Done with page 43
# Done with page 44
# Done with page 45
# Done with page 46
# Done with page 47
# Done with page 48
# Done with page 49
# Done with page 50
# Done with page 51
# Done with page 52
# Done with page 53
# Done with page 54
# Done
# Starting to scrape Big Sean's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done
# Starting to scrape Danny Brown's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done
# Starting to scrape J. Cole's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done
# Starting to scrape Earl Sweatshirt's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done
# Starting to scrape Future's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done
# Starting to scrape Gucci Mane's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done with page 19
# Done with page 20
# Done with page 21
# Done with page 22
# Done with page 23
# Done with page 24
# Done with page 25
# Done with page 26
# Done with page 27
# Done with page 28
# Done with page 29
# Done with page 30
# Done with page 31
# Done with page 32
# Done with page 33
# Done with page 34
# Done with page 35
# Done with page 36
# Done with page 37
# Done with page 38
# Done with page 39
# Done with page 40
# Done
# Starting to scrape JID's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done
# Starting to scrape Lil Uzi Vert's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done
# Starting to scrape 21 Savage's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done
# Starting to scrape Denzel Curry's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done
# Starting to scrape Migos's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done
# Starting to scrape Nas's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done with page 11
# Done with page 12
# Done with page 13
# Done with page 14
# Done with page 15
# Done with page 16
# Done with page 17
# Done with page 18
# Done
# Starting to scrape Schoolboy Q's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done
# Starting to scrape Skepta's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done
# Starting to scrape Vince Staples's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done
# Starting to scrape YG's songs...
# Done with page 1
# Done with page 2
# Done with page 3
# Done with page 4
# Done with page 5
# Done with page 6
# Done with page 7
# Done with page 8
# Done with page 9
# Done with page 10
# Done

# %%
df_songs = pd.DataFrame(all_songs[0])
for songs in all_songs[1:]:
    df_songs = df_songs.append(songs)

# %%
df_songs
# Out:
#                 artist                       title  \
# 0    The Notorious BIG              1970 Somethin’
# 1    The Notorious BIG  1991 Block Party Freestyle
# 2    The Notorious BIG                     Another
# 3    The Notorious BIG          Basement Freestyle
# 4    The Notorious BIG                        Beef
# ..                 ...                         ...
# 180                 YG           Yo Nigga Ain’t Me
# 181                 YG                    Yo Pussy
# 182                 YG               You Betta Kno
# 183                 YG                   You Broke
# 184                 YG                 Youzza Flip
#
#                                                    url  \
# 0    https://genius.com/The-notorious-big-1970-some...
# 1    https://genius.com/The-notorious-big-1991-bloc...
# 2    https://genius.com/The-notorious-big-another-l...
# 3    https://genius.com/The-notorious-big-basement-...
# 4     https://genius.com/The-notorious-big-beef-lyrics
# ..                                                 ...
# 180      https://genius.com/Yg-yo-nigga-aint-me-lyrics
# 181              https://genius.com/Yg-yo-pussy-lyrics
# 182         https://genius.com/Yg-you-betta-kno-lyrics
# 183             https://genius.com/Yg-you-broke-lyrics
# 184           https://genius.com/Yg-youzza-flip-lyrics
#
#                                                 lyrics
# 0    \n\n[Intro: Notorious B.I.G. (Faith Evans)]\n1...
# 1    \n\n[The Notorious B.I.G]\n\nYes it's me, the ...
# 2    \n\n[Intro: Big, Lil' Kim]\nYeah, fuck you\nFu...
# 3    \n\n[Intro: Notorious B.I.G]\nYo\nWe up in the...
# 4    \n\n[Intro: Notorious B.I.G.]\nWe here\nWe ain...
# ..                                                 ...
# 180  \n\nHook: Charlie Hood and YG\nSee shawty be r...
# 181  \n\n[Intro: Raw Smooth]\nRaw Smooth with a ban...
# 182  \n\n[Intro]\nAy, You don't even know it\nI'm o...
# 183  \n\n[Chorus: YG]\nBitch you broke, shut up\nDo...
# 184  \n\n[Verse 1 : Jay 305]\nI'm that nigga, same ...
#
# [6467 rows x 4 columns]

# %%
import string

# %%
df_songs.to_csv('hiphop_lyrics2.csv', index=False)

# %%
df_songs = df_songs.reset_index(drop=True)

# %%
import os

# %%
def clean_lyrics(l):
    l = re.sub(r'[\(\[].*?[\)\]]', '', l)
    l = os.linesep.join([s for s in l.splitlines() if s])
    l = l.replace('\r', '')
    l += '\n'
    l = ''.join([i for i in l if i in string.printable])
    #l = l.replace('\n', '$')
    return l

# %%
df_songs['lyrics'] = df_songs['lyrics'].apply(clean_lyrics)

# %%
lyrics_txt = ''.join(list(df_songs['lyrics']))

# %%
lyrics_txt[:100]
# Out:
# "]\n1970 somethin', 1970 somethin'\n1970 somethin', 1970 somethin' \n1970 somethin', 1970 somethin' \n197"

# %%
with open('lyrics_more.txt', 'w') as file:
    file.write(lyrics_txt)

# %%
lyrics_txt[6200:6300]
# Out:
# "her day$God bid yesterday goodbye$Thought I almost died in my dream again $Fightin' for my life, I\u2005c"

# %%
len(lyrics_txt)
# Out:
# 5407105

# %%
with open('lyrics_more.txt', 'r') as file:
    lyrics_more = file.read()

# %%
with open('lyrics.txt', 'r') as file:
    lyrics = file.read()

# %%
lyrics[-100:]
# Out:
# " the world\nLet's define what my world is\nKnee-deep in this dope money\nDamn near where my world ends\n"

# %%
lyrics_more = lyrics_more.replace('[', '').replace(']', '')

# %%
lyrics_more[1:100]
# Out:
# "1970 somethin', 1970 somethin'\n1970 somethin', 1970 somethin' \n1970 somethin', 1970 somethin' \n1970"

# %%
all_lyrics = lyrics + lyrics_more[1:]

# %%
len(all_lyrics)
# Out:
# 21290845

# %%
with open('all_lyrics.txt', 'w') as file:
    file.write(all_lyrics)
